# %%
# %matplotlib inline
from scrape.graph import create_graph_images, generate_boxplot_ci, generate_boxplot_ci_error, generate_plot_ci_lines

# %%
fig = generate_plot_ci_lines("data")

# %%
fig = generate_boxplot_ci("data")

# %%
fig = generate_boxplot_ci_error("data")
